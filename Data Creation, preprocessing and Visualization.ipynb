# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt

# %%
#file paths
Capture41 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-Honeypot-Capture-4-1\bro\conn.log.labeled"
Capture51 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-Honeypot-Capture-5-1\bro\conn.log.labeled"
Capture71 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-Honeypot-Capture-7-1\Somfy-01\bro\conn.log.labeled"
Capture11 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-1-1\bro\conn.log.labeled"
Capture171 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-17-1\bro\conn.log.labeled"
Capture201 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-20-1\bro\conn.log.labeled"
Capture211 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-21-1\bro\conn.log.labeled"
Capture31 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-3-1\bro\conn.log.labeled"
Capture331 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-33-1\bro\conn.log.labeled"
Capture341 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-34-1\bro\conn.log.labeled"
Capture351 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-35-1\bro\conn.log.labeled"
Capture361 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-36-1\bro\conn.log.labeled"
Capture391 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-39-1\bro\conn.log.labeled"
Capture421 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-42-1\bro\conn.log.labeled"
Capture431 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-43-1\bro\conn.log.labeled"
Capture441 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-44-1\bro\conn.log.labeled"
Capture481 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-48-1\bro\conn.log.labeled"
Capture491 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-49-1\bro\conn.log.labeled"
Capture521 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-52-1\bro\conn.log.labeled"
Capture601 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-60-1\bro\conn.log.labeled"
Capture7_1 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-7-1\bro\conn.log.labeled"
Capture81 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-8-1\bro\conn.log.labeled"
Capture91 = r"D:\Intrusion Detection System (IDS)\opt\Malware-Project\BigDataset\IoTScenarios\CTU-IoT-Malware-Capture-9-1\bro\conn.log.labeled"

# %%
captures=[Capture41,Capture51,Capture71,Capture11,Capture171, Capture201, Capture211, Capture31, Capture331, Capture341, Capture351, Capture361, Capture391, Capture421, Capture431, Capture441, Capture481, Capture491, Capture521, Capture601, Capture7_1, Capture81, Capture91]

# %% [markdown]
# As the dataset is huge, we intend to pick only 50,00,000 records

# %%
column=['ts', 'uid', 'id.orig_h', 'id.orig_p', 'id.resp_h', 'id.resp_p', 'proto', 'service', 'duration', 'orig_bytes', 'resp_bytes', 'conn_state', 'local_orig', 'local_resp', 'missed_bytes', 'history', 'orig_pkts', 'orig_ip_bytes', 'resp_pkts', 'resp_ip_bytes', 'tunnel_parents', 'label', 'detailed-label'] 
frames=[]

dataset_target_size=5000000
sizes=[460,1382,138,1008756,54659863,3209,3286,156111,54454591,23146,10447795,13645106,73568981,4426,67321810,237,3394346,5410561,19781378,3581028,11454722,10403,6378293]
total=sum(sizes)

for i in range(0,len(captures)):
    selection=(sizes[i]/total)*dataset_target_size
    df=pd.read_table(filepath_or_buffer=captures[i],nrows=int(selection),sep="\s+",skiprows=10)
    df.columns=column
    df.drop(df.tail(1).index,inplace=True)
    frames.append(df)
    del df    #command to free memory(is used to delete the reference to a variable or object)

# %%
dataset=pd.concat(frames)
dataset.to_csv("iot23_5kk_combined.csv")

# %%
# column=['ts', 'uid', 'id.orig_h', 'id.orig_p', 'id.resp_h', 'id.resp_p', 'proto', 'service', 'duration', 'orig_bytes', 'resp_bytes', 'conn_state', 'local_orig', 'local_resp', 'missed_bytes', 'history', 'orig_pkts', 'orig_ip_bytes', 'resp_pkts', 'resp_ip_bytes', 'tunnel_parents', 'label', 'detailed-label'] 

# for i in range(0,len(captures)):
#     df= pd.read_table(filepath_or_buffer=captures[i],nrows=100000,sep="\s+",skiprows=10)
#     df.columns=column
#     df.drop(df.tail(1).index,inplace=True)
#     print(df.shape)
#     print(df['label'].value_counts())
#     del df
# Out:
# (449, 23)
# benign    449
# Name: label, dtype: int64
# (1371, 23)
# benign    1371
# Name: label, dtype: int64
# (127, 23)
# benign    127
# Name: label, dtype: int64
# (99999, 23)
# Malicious    55043
# Benign       44956
# Name: label, dtype: int64
# (99999, 23)
# Malicious    99956
# Benign          43
# Name: label, dtype: int64
# (3206, 23)
# Benign       3190
# Malicious      16
# Name: label, dtype: int64
# (3283, 23)
# Benign       3269
# Malicious      14
# Name: label, dtype: int64
# (99999, 23)
# Malicious    96890
# Benign        3109
# Name: label, dtype: int64
# (99999, 23)
# Malicious    97460
# Benign        2539
# Name: label, dtype: int64
# (23142, 23)
# Malicious    21222
# Benign        1920
# Name: label, dtype: int64
# (99999, 23)
# Benign       99917
# Malicious       82
# Name: label, dtype: int64
# (99999, 23)
# Malicious    99978
# Benign          21
# Name: label, dtype: int64
# (99999, 23)
# Malicious    99938
# Benign          61
# ...

# %%
combined=pd.read_csv('iot23_5kk_combined.csv')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4204\3864554451.py:1: DtypeWarning: Columns (9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined=pd.read_csv('iot23_5kk_combined.csv')

# %%
combined
# Out:
#          Unnamed: 0            ts                 uid        id.orig_h  \
# 0                 0  1.540470e+09  CGQf8t1kjdxB5PHXL4    192.168.1.132
# 1                 1  1.540470e+09  CUo9DH2QDnCaBIGjkg    192.168.1.132
# 2                 2  1.540469e+09  CAvXOZ3htimWEtglii    192.168.1.132
# 3                 3  1.540470e+09  CfJsUD2NGQvnK2p7Vd    192.168.1.132
# 4                 4  1.540470e+09   CVwKZS98dRvk1jeH2    192.168.1.132
# ...             ...           ...                 ...              ...
# 4999962       98028  1.532526e+09  COPqjZ1G0gwPbsEJMk  192.168.100.111
# 4999963       98029  1.532526e+09  CaoJDE3qUTeNGc7uJe  192.168.100.111
# 4999964       98030  1.532526e+09  CigkVe17saxHPgbkNf  192.168.100.111
# 4999965       98031  1.532526e+09  CauD1Z2RXEyQgN2gGk  192.168.100.111
# 4999966       98032  1.532526e+09  C9IYvk1hJMfd63ncNi  192.168.100.111
#
#          id.orig_p        id.resp_h  id.resp_p proto service    duration  ...  \
# ...

# %%
# combined = pd.get_dummies(combined, columns=['service'])
# combined['history']= preprocessing.LabelEncoder().fit_transform(combined['history'])
# combined = pd.get_dummies(combined, columns=['proto'])
# combined = pd.get_dummies(combined, columns=['conn_state'])

# %%
combined.shape
# Out:
# (4999967, 24)

# %%
#Encoding the label
#label contains Benign and benign
combined['label']=combined['label'].replace("benign",0)
combined['label']=combined['label'].replace("Benign",0)
combined['label']=combined['label'].replace("Malicious",1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4204\4165670134.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined['label']=combined['label'].replace("Malicious",1)

# %%
def checkdash(c):
    for co in c:
        if "-" in combined[co].unique():
            print(co)
            
checkdash(combined)
# Out:
# service
# duration
# orig_bytes
# resp_bytes
# local_orig
# local_resp
# history
# tunnel_parents
# detailed-label

# %%
combined['service'].unique()
# Out:
# array(['-', 'dns', 'dhcp', 'http', 'ssl', 'irc', 'ssh'], dtype=object)

# %%
# preprocessing for column 'duration'
combined['duration']=combined['duration'].str.replace('-','0')

# %%
combined['orig_bytes'].value_counts()
# Out:
# orig_bytes
# -      3632460
# 0      1212002
# 0       152438
# 48         778
# 96         455
#         ...
# 598          1
# 652          1
# 215          1
# 787          1
# 412          1
# Name: count, Length: 212, dtype: int64

# %%
#replace - with NaN
import numpy as np
combined=combined.replace("-",np.nan)
combined=combined.replace('(empty)',np.nan)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4204\3453438582.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined=combined.replace("-",np.nan)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4204\3453438582.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined=combined.replace('(empty)',np.nan)

# %%
#dectecting missing
def detectmissing(df):
    summary = pd.DataFrame(df.dtypes, columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing(%)'] = df.isnull().sum().values / combined.shape[0]*100  
    summary['Uniques'] = df.nunique().values
    
    return summary
detectmissing(combined)
# Out:
#               Name   dtypes  Missing(%)  Uniques
# 0       Unnamed: 0    int64    0.000000  1130750
# 1               ts  float64    0.000000  4999967
# 2              uid   object    0.000000  4999967
# 3        id.orig_h   object    0.000000     1110
# 4        id.orig_p    int64    0.000000    60405
# 5        id.resp_h   object    0.000000  4809416
# 6        id.resp_p    int64    0.000000     5966
# 7            proto   object    0.000000        3
# 8          service   object   99.984800        6
# 9         duration   object   24.248480    25232
# 10      orig_bytes   object   72.649679      211
# 11      resp_bytes   object   72.649679      239
# 12      conn_state   object    0.000000       13
# 13      local_orig  float64  100.000000        0
# 14      local_resp  float64  100.000000        0
# 15    missed_bytes    int64    0.000000       11
# 16         history   object    0.022700       91
# 17       orig_pkts    int64    0.000000      113
# ...

# %%
combined
# Out:
#          Unnamed: 0            ts                 uid        id.orig_h  \
# 0                 0  1.540470e+09  CGQf8t1kjdxB5PHXL4    192.168.1.132
# 1                 1  1.540470e+09  CUo9DH2QDnCaBIGjkg    192.168.1.132
# 2                 2  1.540469e+09  CAvXOZ3htimWEtglii    192.168.1.132
# 3                 3  1.540470e+09  CfJsUD2NGQvnK2p7Vd    192.168.1.132
# 4                 4  1.540470e+09   CVwKZS98dRvk1jeH2    192.168.1.132
# ...             ...           ...                 ...              ...
# 4999962       98028  1.532526e+09  COPqjZ1G0gwPbsEJMk  192.168.100.111
# 4999963       98029  1.532526e+09  CaoJDE3qUTeNGc7uJe  192.168.100.111
# 4999964       98030  1.532526e+09  CigkVe17saxHPgbkNf  192.168.100.111
# 4999965       98031  1.532526e+09  CauD1Z2RXEyQgN2gGk  192.168.100.111
# 4999966       98032  1.532526e+09  C9IYvk1hJMfd63ncNi  192.168.100.111
#
#          id.orig_p        id.resp_h  id.resp_p proto service    duration  ...  \
# ...

# %%
# dropping unrequired labels
combined=combined.drop(labels=['tunnel_parents','local_orig','local_resp','uid','id.orig_h','id.resp_h','detailed-label'],axis=1)

# %%
combined['id.orig_p']=pd.to_numeric(combined['id.orig_p'])
combined['duration']=combined['duration'].astype(float)
combined['orig_bytes']=combined['orig_bytes'].astype(float)
combined['resp_bytes']=combined['resp_bytes'].astype(float)
combined['ts']=combined['ts'].astype(float)
# combined['proto']=combined['proto'].astype("string")
# combined['service']=combined['service'].astype("string")
# combined['conn_state']=combined['conn_state'].astype("string")

# %%
detectmissing(combined)
# Out:
#              Name   dtypes  Missing(%)  Uniques
# 0      Unnamed: 0    int64    0.000000  1130750
# 1              ts  float64    0.000000  4999967
# 2       id.orig_p    int64    0.000000    60405
# 3       id.resp_p    int64    0.000000     5966
# 4           proto   object    0.000000        3
# 5         service   object   99.984800        6
# 6        duration  float64   24.248480    24600
# 7      orig_bytes  float64   72.649679      194
# 8      resp_bytes  float64   72.649679      237
# 9      conn_state   object    0.000000       13
# 10   missed_bytes    int64    0.000000       11
# 11        history   object    0.022700       91
# 12      orig_pkts    int64    0.000000      113
# 13  orig_ip_bytes    int64    0.000000      340
# 14      resp_pkts    int64    0.000000       90
# 15  resp_ip_bytes    int64    0.000000      282
# 16          label    int64    0.000000        2

# %%
combined['proto'].unique()
# Out:
# array(['tcp', 'udp', 'icmp'], dtype=object)

# %%
combined['conn_state'].unique()
# Out:
# array(['SF', 'S0', 'RSTO', 'REJ', 'OTH', 'RSTOS0', 'RSTR', 'S2', 'RSTRH',
#        'S1', 'S3', 'SH', 'SHR'], dtype=object)

# %%
combined['service']= preprocessing.LabelEncoder().fit_transform(combined['service'])
combined['proto']= preprocessing.LabelEncoder().fit_transform(combined['proto'])
combined['conn_state']= preprocessing.LabelEncoder().fit_transform(combined['conn_state'])
combined['history']= preprocessing.LabelEncoder().fit_transform(combined['history'])
combined
# Out:
#          Unnamed: 0            ts  id.orig_p  id.resp_p  proto  service  \
# 0                 0  1.540470e+09      53395        443      1        6
# 1                 1  1.540470e+09      52801         53      2        1
# 2                 2  1.540469e+09       1900       1900      2        6
# 3                 3  1.540470e+09      58124        123      2        6
# 4                 4  1.540470e+09      35313        123      2        6
# ...             ...           ...        ...        ...    ...      ...
# 4999962       98028  1.532526e+09      33445         81      1        6
# 4999963       98029  1.532526e+09      26793         81      1        6
# 4999964       98030  1.532526e+09      12787         81      1        6
# 4999965       98031  1.532526e+09      60706         81      1        6
# 4999966       98032  1.532526e+09      60477         81      1        6
#
#            duration  orig_bytes  resp_bytes  conn_state  missed_bytes  \
# ...

# %%
combined.isnull().values.any()
# Out:
# True

# %%
# data imputation
combined.fillna(0,inplace=True)
# combined.fillna(-1,inplace=True)
#fills any missing (NaN) values in the DataFrame 'combined' with the value -1. The inplace=True argument means that the operation modifies the original DataFrame directly.

# %%
combined.isnull().values.any()
# Out:
# False

# %%
# # scaling for reducing computation costs
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# scaled = scaler.fit_transform(combined)
# # combined = scaler.fit_transform(combined)

# %%
# scaled

# %%
combined['missed_bytes'].value_counts()
# Out:
# missed_bytes
# 0        4999928
# 2896          10
# 1448           9
# 5792           6
# 10136          4
# 4344           3
# 2920           2
# 7240           2
# 1460           1
# 13032          1
# 15928          1
# Name: count, dtype: int64

# %%
combined.nunique()
# Out:
# Unnamed: 0       1130750
# ts               4999967
# id.orig_p          60405
# id.resp_p           5966
# proto                  3
# service                7
# duration           24600
# orig_bytes           194
# resp_bytes           237
# conn_state            13
# missed_bytes          11
# history               92
# orig_pkts            113
# orig_ip_bytes        340
# resp_pkts             90
# resp_ip_bytes        282
# label                  2
# dtype: int64

# %%
combined['Unnamed: 0'].value_counts()
# Out:
# Unnamed: 0
# 0          23
# 1          22
# 2          21
# 3          21
# 4          21
#            ..
# 1066734     1
# 1066733     1
# 1066732     1
# 1066731     1
# 1130749     1
# Name: count, Length: 1130750, dtype: int64

# %%
combined
# Out:
#          Unnamed: 0            ts  id.orig_p  id.resp_p  proto  service  \
# 0                 0  1.540470e+09      53395        443      1        6
# 1                 1  1.540470e+09      52801         53      2        1
# 2                 2  1.540469e+09       1900       1900      2        6
# 3                 3  1.540470e+09      58124        123      2        6
# 4                 4  1.540470e+09      35313        123      2        6
# ...             ...           ...        ...        ...    ...      ...
# 4999962       98028  1.532526e+09      33445         81      1        6
# 4999963       98029  1.532526e+09      26793         81      1        6
# 4999964       98030  1.532526e+09      12787         81      1        6
# 4999965       98031  1.532526e+09      60706         81      1        6
# 4999966       98032  1.532526e+09      60477         81      1        6
#
#            duration  orig_bytes  resp_bytes  conn_state  missed_bytes  \
# ...

# %%
# dropping unrequired labels
combined=combined.drop(labels=['Unnamed: 0','duration','orig_bytes','resp_bytes','missed_bytes','history'],axis=1)

# %%
combined.corr(numeric_only=True)
# Out:
#                Unnamed: 0        ts  id.orig_p  id.resp_p     proto   service  \
# Unnamed: 0       1.000000  0.042395   0.046206  -0.021632 -0.043849  0.013046
# ts               0.042395  1.000000   0.577912  -0.093733 -0.079769  0.005332
# id.orig_p        0.046206  0.577912   1.000000  -0.324042  0.006699 -0.006469
# id.resp_p       -0.021632 -0.093733  -0.324042   1.000000  0.013955  0.009950
# proto           -0.043849 -0.079769   0.006699   0.013955  1.000000 -0.208998
# service          0.013046  0.005332  -0.006469   0.009950 -0.208998  1.000000
# duration        -0.057382  0.022042   0.035060  -0.039405 -0.004245  0.001050
# orig_bytes      -0.001114  0.003529   0.000350   0.000075  0.019595  0.000007
# resp_bytes      -0.000971  0.000358   0.000161  -0.000654  0.000173 -0.053006
# conn_state       0.123141 -0.414045   0.027798  -0.196843  0.099010 -0.041475
# missed_bytes    -0.002869  0.000853   0.000484  -0.001903 -0.000075 -0.157555
# ...

# %%
features = combined.drop('label', axis=1)
column_names =features.columns
correlations = features.corr()
print(correlations)
# Plot figsize
fig, ax = plt.subplots(figsize=(15,11))
# Generate Color Map
colormap = sns.diverging_palette(256, 15, as_cmap=True)
# Generate Heat Map, allow annotations and place floats in map
sns.heatmap(correlations, cmap=colormap, annot=True, fmt=".2f")
ax.set_xticklabels(
    column_names,
    rotation=45,
    horizontalalignment='right'
);
ax.set_yticklabels(column_names);
# Out:
#                Unnamed: 0        ts  id.orig_p  id.resp_p     proto   service  \
# Unnamed: 0       1.000000  0.042395   0.046206  -0.021632 -0.043849  0.013046
# ts               0.042395  1.000000   0.577912  -0.093733 -0.079769  0.005332
# id.orig_p        0.046206  0.577912   1.000000  -0.324042  0.006699 -0.006469
# id.resp_p       -0.021632 -0.093733  -0.324042   1.000000  0.013955  0.009950
# proto           -0.043849 -0.079769   0.006699   0.013955  1.000000 -0.208998
# service          0.013046  0.005332  -0.006469   0.009950 -0.208998  1.000000
# duration        -0.057382  0.022042   0.035060  -0.039405 -0.004245  0.001050
# orig_bytes      -0.001114  0.003529   0.000350   0.000075  0.019595  0.000007
# resp_bytes      -0.000971  0.000358   0.000161  -0.000654  0.000173 -0.053006
# conn_state       0.123141 -0.414045   0.027798  -0.196843  0.099010 -0.041475
# missed_bytes    -0.002869  0.000853   0.000484  -0.001903 -0.000075 -0.157555
# ...

# %% [markdown]
# As co-relation between resp_pkts and resp_ip_bytes is very high, we drop one of those columns.
# As co-relation between orig_pkts and orig_ip_bytes is very high, we drop one of those columns.

# %%
combined=combined.drop(labels=['resp_pkts','orig_ip_bytes'],axis=1)

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.naive_bayes import GaussianNB
# y=combined['label']
# X=combined.drop(labels=['label'],axis=1)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
# gnb = GaussianNB()
# y_pred = gnb.fit(X_train, y_train).predict(X_test)
# print(((y_test == y_pred).sum())/X_test.shape[0])

# %%
combined
# Out:
#          Unnamed: 0            ts  id.orig_p  id.resp_p  proto  service  \
# 0                 0  1.540470e+09      53395        443      1        6
# 1                 1  1.540470e+09      52801         53      2        1
# 2                 2  1.540469e+09       1900       1900      2        6
# 3                 3  1.540470e+09      58124        123      2        6
# 4                 4  1.540470e+09      35313        123      2        6
# ...             ...           ...        ...        ...    ...      ...
# 4999962       98028  1.532526e+09      33445         81      1        6
# 4999963       98029  1.532526e+09      26793         81      1        6
# 4999964       98030  1.532526e+09      12787         81      1        6
# 4999965       98031  1.532526e+09      60706         81      1        6
# 4999966       98032  1.532526e+09      60477         81      1        6
#
#            duration  orig_bytes  resp_bytes  conn_state  missed_bytes  \
# ...

# %%
combined= combined.drop('Unnamed: 0', axis = 1)

# %%
combined
# Out:
#                    ts  id.orig_p  id.resp_p  proto  service    duration  \
# 0        1.540470e+09      53395        443      1        6    0.003497
# 1        1.540470e+09      52801         53      2        1    0.036724
# 2        1.540469e+09       1900       1900      2        6  384.518261
# 3        1.540470e+09      58124        123      2        6    0.270332
# 4        1.540470e+09      35313        123      2        6    0.111429
# ...               ...        ...        ...    ...      ...         ...
# 4999962  1.532526e+09      33445         81      1        6    0.000000
# 4999963  1.532526e+09      26793         81      1        6    0.000000
# 4999964  1.532526e+09      12787         81      1        6    0.000000
# 4999965  1.532526e+09      60706         81      1        6    0.000000
# 4999966  1.532526e+09      60477         81      1        6    0.000000
#
#          orig_bytes  resp_bytes  conn_state  missed_bytes  history  orig_pkts  \
# ...

# %%
#imp for big datasets
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))

    return df

# %%
reduce_mem_usage(combined)
# Out:
# Memory usage after optimization is: 185.97 MB
# Decreased by 59.4%
#                    ts  id.orig_p  id.resp_p  proto  service    duration  \
# 0        1.540470e+09      53395        443      1        6    0.003497
# 1        1.540470e+09      52801         53      2        1    0.036724
# 2        1.540469e+09       1900       1900      2        6  384.518250
# 3        1.540470e+09      58124        123      2        6    0.270332
# 4        1.540470e+09      35313        123      2        6    0.111429
# ...               ...        ...        ...    ...      ...         ...
# 4999962  1.532526e+09      33445         81      1        6    0.000000
# 4999963  1.532526e+09      26793         81      1        6    0.000000
# 4999964  1.532526e+09      12787         81      1        6    0.000000
# 4999965  1.532526e+09      60706         81      1        6    0.000000
# 4999966  1.532526e+09      60477         81      1        6    0.000000
#
# ...

# %%
combined.columns.tolist()
# Out:
# ['ts',
#  'id.orig_p',
#  'id.resp_p',
#  'proto',
#  'service',
#  'duration',
#  'orig_bytes',
#  'resp_bytes',
#  'conn_state',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'resp_ip_bytes',
#  'label']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# dataset=pd.read_csv("iot23_combined.csv")

combined['label']=combined['label'].replace("benign",0)
combined['label']=combined['label'].replace("Benign",0)
combined['label']=combined['label'].replace("Malicious",1)

plt.figure(figsize=(6, 5))
yaxis = combined['label'].value_counts().values / combined.shape[0]
barplot = sns.barplot(x=[1,0], y=yaxis, palette = 'pastel')
for p in barplot.patches:
    barplot.annotate(format(p.get_height()*100, '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')
plt.title("Malware Distribution for Combined Dataset \n 0: Benign | 1: Malicious ")
plt.xlabel('Is Malicious?')
plt.ylabel('Percentage')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# Text(0, 0.5, 'Percentage')
